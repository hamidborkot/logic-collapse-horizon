# %% [markdown]
# # 🧠 Logic Collapse Horizon — Full Pipeline
# **Paper**: *Logic Collapse Horizon: When Compressed Neural Networks Lose Their Reasoning*
#
# This notebook trains all models and runs all 3 novel experiments end-to-end.
#
# **Runtime**: ~25 min on Colab CPU | ~8 min on T4 GPU
#
# ---

# %%
# Install dependencies
# !pip install -q shap ucimlrepo scikit-learn scipy matplotlib numpy pandas torch tqdm

# %%
# Clone repo
# !git clone https://github.com/hamidborkot/logic-collapse-horizon.git
import os; os.chdir('logic-collapse-horizon')

# %% [markdown]
# ## Step 1 — Train All Models

# %%
# Full training pipeline (teacher + LoRA-SHAP + VanillaLoRA + KD + Pruning)
# See src/train.py for full details
exec(open('src/train.py').read())
MODELS = main()

# %% [markdown]
# ## Step 2 — Experiment 1: CKA–LCI Theorem

# %%
from src.experiments import run_exp1
df1, r_cka, p_cka = run_exp1(MODELS, MODELS['Teacher'], Xbg, Xq)

# %% [markdown]
# ## Step 3 — Experiment 2: SEPA / MPRF Attack

# %%
from src.experiments import run_exp2
lci_map = {n: df1[df1.Method==n].LCI.values[0] if n!='Teacher' else 1.0 for n in MODELS}
df2, r_mprf, p_mprf = run_exp2(MODELS, MODELS['Teacher'], Xq, lci_map)

# %% [markdown]
# ## Step 4 — Experiment 3: ESC / TRS Certification

# %%
from src.experiments import run_exp3
trs_data, df3 = run_exp3(MODELS, MODELS['Teacher'], Xq)

# %% [markdown]
# ## Step 5 — Generate All Figures

# %%
# Figures are generated inline — see src/figures.py for standalone use
# !python src/figures.py
